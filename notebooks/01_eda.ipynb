# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud,STOPWORDS

# %% [markdown]
# # Data
# The following data is intended for advancing financial sentiment analysis research. It's two datasets (FiQA, Financial PhraseBank) combined into one easy-to-use CSV file. It provides financial sentences with sentiment labels.
#
# # Citations
# Malo, Pekka, et al. "Good debt or bad debt: Detecting semantic orientations in economic texts." Journal of the Association for Information Science and Technology 65.4 (2014): 782-796.

# %% [markdown]
# # EDA

# %%
pd.set_option('display.max_colwidth', None)
df = pd.read_csv("../data/data.csv")
df.head(n = 20)
# Out:
#                                                                                                                                                                                                                            Sentence  \
# 0        The GeoSolutions technology will leverage Benefon 's GPS solutions by providing Location Based Search Technology , a Communities Platform , location relevant multimedia content and a new and powerful commercial model .
# 1                                                                                                                                                                           $ESI on lows, down $1.50 to $2.50 BK a real possibility
# 2                                 For the last quarter of 2010 , Componenta 's net sales doubled to EUR131m from EUR76m for the same period a year earlier , while it moved to a zero pre-tax profit from a pre-tax loss of EUR7m .
# ...

# %%
df.shape
# Out:
# (5842, 2)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5842 entries, 0 to 5841
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Sentence   5842 non-null   str
#  1   Sentiment  5842 non-null   str
# dtypes: str(2)
# memory usage: 801.8 KB

# %%
# max length of the sentences
df['sentence_length'] = df['Sentence'].str.len()

print("Summary of the length of the sentences:", df['sentence_length'].describe())

# Get the longest sentence itself
print("The longest sentence:", df.loc[df['Sentence'].str.len().idxmax(), 'Sentence'])
# Out:
# Summary of the length of the sentences: count    5842.000000
# mean      117.022253
# std        56.420425
# min         9.000000
# 25%        72.000000
# 50%       107.000000
# 75%       150.000000
# max       315.000000
# Name: sentence_length, dtype: float64
# The longest sentence: Supported Nokia phones include : N96 , N95-8GB , N95 , N93-N931 , N92 , N85 , N82 , N81 , N80 , N79 , N78 , N77 , N76 , N75 , N73 , N72 , N71 , E90 , E71 , E70 , E66 , E65 , E62 , E61-E61i , E60 , E51 , E50 , Touch Xpress 5800 , 6220 Classic , 6210 Navigator , 6120 Classic , 6110 Navigator , 5700 , 5500 , 5320XM .

# %%
sns.countplot(x ='Sentiment', data = df)
plt.show()

# %%
# Sentiment Positive

df1 = df[df['Sentiment']=='positive']
words = ' '.join(df1['Sentence'].astype(str))
cleaned_word = ' '.join([word for word in words.split() if not word.startswith('@')])

wordcloud = WordCloud(background_color='black',stopwords=STOPWORDS,
                      width=3000, height=2500).generate(''.join(cleaned_word))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# Sentiment Negative

df1 = df[df['Sentiment']=='negative']
words = ' '.join(df1['Sentence'].astype(str))
cleaned_word = ' '.join([word for word in words.split() if not word.startswith('@')])

wordcloud = WordCloud(background_color='black',stopwords=STOPWORDS,
                      width=3000, height=2500).generate(''.join(cleaned_word))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# Sentiment neutral

df1 = df[df['Sentiment']=='positive']
words = ' '.join(df1['Sentence'].astype(str))
cleaned_word = ' '.join([word for word in words.split() if not word.startswith('@')])

wordcloud = WordCloud(background_color='black',stopwords=STOPWORDS,
                      width=3000, height=2500).generate(''.join(cleaned_word))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
